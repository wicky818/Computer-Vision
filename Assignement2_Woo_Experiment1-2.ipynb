# %%
import datetime
import time
import numpy as np
import pandas as pd
from packaging import version
from collections import Counter

from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split
from sklearn.manifold import TSNE

import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import models, layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, BatchNormalization, Dropout, Flatten, Input, Dense
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import to_categorical

# %%
# %matplotlib inline
np.set_printoptions(precision=3, suppress=True)

# %%
def print_validation_report(y_test, predictions):
    print("Classification Report")
    print(classification_report(y_test, predictions))
    print('Accuracy Score: {}'.format(accuracy_score(y_test, predictions)))
    print('Root Mean Square Error: {}'.format(np.sqrt(MSE(y_test, predictions))))

# %%
def plot_confusion_matrix(y_true, y_pred):
    mtx = confusion_matrix(y_true, y_pred)
    fig, ax = plt.subplots(figsize=(8,8))
    sns.heatmap(mtx, annot=True, fmt='d', linewidths=.75,  cbar=False, ax=ax,cmap='Blues',linecolor='white')
    #  square=True,
    plt.ylabel('true label')
    plt.xlabel('predicted label')

# %%
#Loading Data

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.cifar10.load_data()

# %%
print('train_images:\t{}'.format(x_train.shape))
print('train_labels:\t{}'.format(y_train.shape))
print('test_images:\t{}'.format(x_test.shape))
print('test_labels:\t{}'.format(y_test.shape))
# Out:
# train_images:	(50000, 32, 32, 3)
# train_labels:	(50000, 1)
# test_images:	(10000, 32, 32, 3)
# test_labels:	(10000, 1)

# %%
def get_three_classes(x, y):
    def indices_of(class_id):
        indices, _ = np.where(y == float(class_id))
        return indices

    indices = np.concatenate([indices_of(0), indices_of(1), indices_of(2)], axis=0)
    
    x = x[indices]
    y = y[indices]
    
    count = x.shape[0]
    indices = np.random.choice(range(count), count, replace=False)
    
    x = x[indices]
    y = y[indices]
    
    y = tf.keras.utils.to_categorical(y)
    
    return x, y

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %%
x_preview, y_preview = get_three_classes(train_images, train_labels)
#x_preview, y_preview = get_three_classes(test_images, test_labels)

# %%
class_names_preview = ['aeroplane', 'car', 'bird']

def show_random_examples(x, y, p):
    indices = np.random.choice(range(x.shape[0]), 10, replace=False)
    
    x = x[indices]
    y = y[indices]
    p = p[indices]
    
    plt.figure(figsize=(10, 5))
    for i in range(10):
        plt.subplot(2, 5, i + 1)
        plt.imshow(x[i])
        plt.xticks([])
        plt.yticks([])
        col = 'green' if np.argmax(y[i]) == np.argmax(p[i]) else 'red'
        plt.xlabel(class_names_preview[np.argmax(p[i])], color=col)
    plt.show()

show_random_examples(x_preview, y_preview, y_preview)

# %% [markdown]
# The labels are an array of integers, ranging from 0 to 9. These correspond to the class of clothing the image represents:
#
# |Label  |Class_  |
# |-------|--------|
# |0|	airplane     |
# |1|	automobile   |
# |2|	bird         |
# |3|	cat          |
# |4|	deer         |
# |5|	dog          |
# |6|	frog         |
# |7|	horse        |
# |8|	ship         |
# |9|	truck        |

# %%
class_names = ['airplane'
,'automobile'
,'bird'
,'cat'
,'deer'
,'dog'
,'frog' 
,'horse'
,'ship'
,'truck']

# %%
x_train_split, x_valid_split, y_train_split, y_valid_split = train_test_split(x_train
                                                                              ,y_train
                                                                              ,test_size=.1
                                                                              ,random_state=42
                                                                              ,shuffle=True)

# %%
print(x_train_split.shape, x_valid_split.shape, x_test.shape)
# Out:
# (45000, 32, 32, 3) (5000, 32, 32, 3) (10000, 32, 32, 3)

# %%
x_train_norm = x_train_split/255
x_valid_norm = x_valid_split/255
x_test_norm = x_test/255

# %%
results = []

# %% [markdown]
# ## Experiment 0.5: DNN with 1 layer (no regularization)

# %%
model = models.Sequential()
model.add(layers.Flatten(input_shape=(32,32,3)))
model.add(layers.Dense(units=384, activation=tf.nn.relu))
#model.add(layers.Dense(units=128, activation=tf.nn.relu))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 3072)              0
# _________________________________________________________________
# dense (Dense)                (None, 384)               1180032
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                3850
# =================================================================
# Total params: 1,183,882
# Trainable params: 1,183,882
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
history = model.fit(x_train_norm
                    ,y_train_split
                    ,epochs=200
                    ,batch_size=100
                    ,validation_data=(x_valid_norm, y_valid_split)
                    ,callbacks=[
                    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    tf.keras.callbacks.ModelCheckpoint('/mnt/Assignement2/models/model_{val_accuracy:.4f}.h5', save_best_only=True,
                                        save_weights_only=False, monitor='val_accuracy')]                                                                                                           
                   )
# Out:
# Epoch 1/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.9852 - accuracy: 0.3081 - val_loss: 1.8515 - val_accuracy: 0.3286
# Epoch 2/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.7631 - accuracy: 0.3716 - val_loss: 1.7429 - val_accuracy: 0.3680
# Epoch 3/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.6780 - accuracy: 0.4041 - val_loss: 1.6867 - val_accuracy: 0.3878
# Epoch 4/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.6319 - accuracy: 0.4192 - val_loss: 1.6670 - val_accuracy: 0.4014
# Epoch 5/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.5953 - accuracy: 0.4335 - val_loss: 1.6536 - val_accuracy: 0.4138
# Epoch 6/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.5616 - accuracy: 0.4457 - val_loss: 1.6122 - val_accuracy: 0.4306
# Epoch 7/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.5381 - accuracy: 0.4546 - val_loss: 1.5780 - val_accuracy: 0.4274
# Epoch 8/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.5175 - accuracy: 0.4630 - val_loss: 1.5948 - val_accuracy: 0.4284
# Epoch 9/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4948 - accuracy: 0.4693 - val_loss: 1.5474 - val_accuracy: 0.4490
# Epoch 10/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4827 - accuracy: 0.4734 - val_loss: 1.6483 - val_accuracy: 0.4116
# Epoch 11/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4704 - accuracy: 0.4784 - val_loss: 1.5654 - val_accuracy: 0.4364
# Epoch 12/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4544 - accuracy: 0.4857 - val_loss: 1.5497 - val_accuracy: 0.4492
# Epoch 13/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4453 - accuracy: 0.4864 - val_loss: 1.5664 - val_accuracy: 0.4376
# Epoch 14/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4306 - accuracy: 0.4932 - val_loss: 1.5214 - val_accuracy: 0.4546
# Epoch 15/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4206 - accuracy: 0.4973 - val_loss: 1.5151 - val_accuracy: 0.4538
# Epoch 16/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4172 - accuracy: 0.4984 - val_loss: 1.5201 - val_accuracy: 0.4552
# Epoch 17/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4040 - accuracy: 0.5049 - val_loss: 1.4901 - val_accuracy: 0.4710
# Epoch 18/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3870 - accuracy: 0.5081 - val_loss: 1.5072 - val_accuracy: 0.4672
# Epoch 19/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3829 - accuracy: 0.5116 - val_loss: 1.4803 - val_accuracy: 0.4694
# Epoch 20/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3783 - accuracy: 0.5096 - val_loss: 1.5017 - val_accuracy: 0.4696

# %%
history_dict = history.history
history_dict.keys()
history_df=pd.DataFrame(history_dict)

# %%
train_losses = history.history["loss"]
train_accs = history.history["accuracy"]
val_losses = history.history["val_loss"]
val_accs = history.history["val_accuracy"]
epochs = len(train_losses)

# %%
loss, accuracy = model.evaluate(x_test_norm, y_test)
print('ttest se accuracy: ', accuracy * 100, "%")
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4766 - accuracy: 0.4767
# ttest se accuracy:  47.67000079154968 %

# %%
plt.figure(figsize=(16, 4))
for i, metrics in enumerate(zip([train_losses, train_accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %%
result_1 = {"Experiemnt": "Experiment 0.5: DNN with 1 Layer w/o reg", "Test_Accuracy": accuracy,
            "loss": loss, "Train_Accuracy":train_accs[-1], "Train_Loss":train_losses[-1],
            "Val_Accuracy":val_accs[-1],
           "Val_Loss":val_losses[-1]}
results.append(result_1)

# %% [markdown]
# ## Experiment 1: DNN with 2 layers (no regularization)

# %%
model = models.Sequential()
model.add(layers.Flatten(input_shape=(32,32,3)))
model.add(layers.Dense(units=384, activation=tf.nn.relu))
model.add(layers.Dense(units=384, activation=tf.nn.relu))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 3072)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 384)               1180032
# _________________________________________________________________
# dense_3 (Dense)              (None, 384)               147840
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                3850
# =================================================================
# Total params: 1,331,722
# Trainable params: 1,331,722
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
history = model.fit(x_train_norm
                    ,y_train_split
                    ,epochs=200
                    ,batch_size=100
                    ,validation_data=(x_valid_norm, y_valid_split)
                    ,callbacks=[
                    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    tf.keras.callbacks.ModelCheckpoint('/mnt/Assignement2/models/model_{val_accuracy:.4f}.h5', save_best_only=True,
                                        save_weights_only=False, monitor='val_accuracy')]                                                                                                           
                   )
# Out:
# Epoch 1/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.8923 - accuracy: 0.3208 - val_loss: 1.7586 - val_accuracy: 0.3620
# Epoch 2/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.6819 - accuracy: 0.3988 - val_loss: 1.6573 - val_accuracy: 0.4032
# Epoch 3/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.5973 - accuracy: 0.4300 - val_loss: 1.6062 - val_accuracy: 0.4234
# Epoch 4/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.5327 - accuracy: 0.4538 - val_loss: 1.5528 - val_accuracy: 0.4472
# Epoch 5/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4901 - accuracy: 0.4687 - val_loss: 1.5497 - val_accuracy: 0.4388
# Epoch 6/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4571 - accuracy: 0.4826 - val_loss: 1.5029 - val_accuracy: 0.4616
# Epoch 7/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4250 - accuracy: 0.4948 - val_loss: 1.4994 - val_accuracy: 0.4666
# Epoch 8/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3993 - accuracy: 0.5006 - val_loss: 1.5227 - val_accuracy: 0.4538
# Epoch 9/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3706 - accuracy: 0.5117 - val_loss: 1.4869 - val_accuracy: 0.4698
# Epoch 10/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3461 - accuracy: 0.5188 - val_loss: 1.4502 - val_accuracy: 0.4790
# Epoch 11/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3260 - accuracy: 0.5266 - val_loss: 1.4474 - val_accuracy: 0.4786
# Epoch 12/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.2999 - accuracy: 0.5371 - val_loss: 1.4705 - val_accuracy: 0.4684
# Epoch 13/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.2891 - accuracy: 0.5399 - val_loss: 1.4661 - val_accuracy: 0.4760

# %%
loss, accuracy = model.evaluate(x_test_norm, y_test)
print('test set accuracy: ', accuracy * 100, "%")
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4477 - accuracy: 0.4863
# test set accuracy:  48.6299991607666 %

# %%
history_dict = history.history
history_dict.keys()
history_df=pd.DataFrame(history_dict)

# %%
train_losses = history.history["loss"]
train_accs = history.history["accuracy"]
val_losses = history.history["val_loss"]
val_accs = history.history["val_accuracy"]
epochs = len(train_losses)

# %%
plt.figure(figsize=(16, 4))
for i, metrics in enumerate(zip([train_losses, train_accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %%
result_2 = {"Experiemnt": "Experiment 1: DNN with 2 Layer w/o reg", "Test_Accuracy": accuracy,
            "loss": loss, "Train_Accuracy":train_accs[-1], "Train_Loss":train_losses[-1],
            "Val_Accuracy":val_accs[-1],
            "Val_Loss":val_losses[-1]}
results.append(result_2)

# %% [markdown]
# ## Experiment 2: DNN with 3 layers (no regularization)

# %%
model = models.Sequential()
model.add(layers.Flatten(input_shape=(32,32,3)))
model.add(layers.Dense(units=384, activation=tf.nn.relu))
model.add(layers.Dense(units=384, activation=tf.nn.relu))
model.add(layers.Dense(units=384, activation=tf.nn.relu))
model.add(layers.Dense(units=10, activation=tf.nn.softmax))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %%
history = model.fit(x_train_norm
                    ,y_train_split
                    ,epochs=200
                    ,batch_size=100
                    ,validation_data=(x_valid_norm, y_valid_split)
                    ,callbacks=[
                    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', patience=3),
                    tf.keras.callbacks.ModelCheckpoint('/mnt/Assignement2/models/model_{val_accuracy:.4f}.h5', save_best_only=True,
                                        save_weights_only=False, monitor='val_accuracy')]                                                                                                           
                   )
# Out:
# Epoch 1/200
# 450/450 [==============================] - 1s 3ms/step - loss: 1.8584 - accuracy: 0.3260 - val_loss: 1.7583 - val_accuracy: 0.3644
# Epoch 2/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.6704 - accuracy: 0.4036 - val_loss: 1.6308 - val_accuracy: 0.4190
# Epoch 3/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.5810 - accuracy: 0.4347 - val_loss: 1.5845 - val_accuracy: 0.4302
# Epoch 4/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.5203 - accuracy: 0.4556 - val_loss: 1.5374 - val_accuracy: 0.4470
# Epoch 5/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4665 - accuracy: 0.4777 - val_loss: 1.5393 - val_accuracy: 0.4368
# Epoch 6/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.4390 - accuracy: 0.4859 - val_loss: 1.5128 - val_accuracy: 0.4530
# Epoch 7/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3962 - accuracy: 0.5027 - val_loss: 1.4950 - val_accuracy: 0.4694
# Epoch 8/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3640 - accuracy: 0.5133 - val_loss: 1.4929 - val_accuracy: 0.4658
# Epoch 9/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.3278 - accuracy: 0.5222 - val_loss: 1.4388 - val_accuracy: 0.4866
# Epoch 10/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.2972 - accuracy: 0.5335 - val_loss: 1.4576 - val_accuracy: 0.4774
# Epoch 11/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.2654 - accuracy: 0.5443 - val_loss: 1.4703 - val_accuracy: 0.4728
# Epoch 12/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.2393 - accuracy: 0.5546 - val_loss: 1.4347 - val_accuracy: 0.4914
# Epoch 13/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.2023 - accuracy: 0.5701 - val_loss: 1.4295 - val_accuracy: 0.4998
# Epoch 14/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.1616 - accuracy: 0.5830 - val_loss: 1.4387 - val_accuracy: 0.4946
# Epoch 15/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.1405 - accuracy: 0.5901 - val_loss: 1.4783 - val_accuracy: 0.4906
# Epoch 16/200
# 450/450 [==============================] - 1s 2ms/step - loss: 1.1115 - accuracy: 0.6000 - val_loss: 1.4819 - val_accuracy: 0.4892

# %%
history_dict = history.history
history_dict.keys()
history_df=pd.DataFrame(history_dict)

# %%
train_losses = history.history["loss"]
train_accs = history.history["accuracy"]
val_losses = history.history["val_loss"]
val_accs = history.history["val_accuracy"]
epochs = len(train_losses)

# %%
loss, accuracy = model.evaluate(x_test_norm, y_test)
print('test set accuracy: ', accuracy * 100, "%")
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 1.4677 - accuracy: 0.5026
# test set accuracy:  50.26000142097473 %

# %%
plt.figure(figsize=(16, 4))
for i, metrics in enumerate(zip([train_losses, train_accs], [val_losses, val_accs], ['Loss', 'Accuracy'])):
    plt.subplot(1, 2, i + 1)
    plt.plot(range(epochs), metrics[0], label='Training {}'.format(metrics[2]))
    plt.plot(range(epochs), metrics[1], label='Validation {}'.format(metrics[2]))
    plt.legend()
plt.show()

# %%
result_3 = {"Experiemnt": "Experiment 2: DNN with 3 Layer w/o reg", "Test_Accuracy": accuracy,
            "loss": loss, "Train_Accuracy":train_accs[-1], "Train_Loss":train_losses[-1],
            "Val_Accuracy":val_accs[-1],
           "Val_Loss":val_losses[-1]}
results.append(result_3)

# %%
results_df = pd.DataFrame(results)

# %%
results_df.to_csv("exp1&2_output.csv", index=False)

# %% [markdown]
# ## Please see Assignment2_Woo-Experiement3-4.ipynb to continue
